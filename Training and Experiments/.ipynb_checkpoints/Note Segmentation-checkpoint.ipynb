# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import essentia.standard as es
import madmom
import IPython
import pickle
from pickle import load
from scipy.signal import find_peaks

# %%
# Onset detection using Spectral Onset Processor
def onset_SOP(audiofile):
    #Detection function
    fps = 200
    sodf = madmom.features.onsets.SpectralOnsetProcessor('superflux', diff_frames=20)
    sodf.processors[-1]  # doctest: +ELLIPSIS
    det_function = sodf(audiofile, fps = fps)
    det_function_norm = det_function/(max(det_function))

    #Dynamic threashold
    C_t = 0.99
    H = 100
    delta = 0.1

    din_th = np.zeros(len(det_function_norm))
    for m in range(H, len(det_function_norm)):
        din_th[m] = C_t*np.median(det_function_norm[m-H:m+H])+delta

    #Peak detection
    peaks, _ = find_peaks(det_function_norm, distance=fps/10, height = din_th)  
    onset_array = peaks/fps
    
    return onset_array

# %%
audiofile = 'The_Guvnor_Sax.mp3'
#audiofile = 'C_Major_Scale_Sax_Legato3.mp3'
fs = 44100
# Loading audio file
x = es.MonoLoader(filename=audiofile)()
IPython.display.Audio(audiofile, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Extract samples where the onsets happen
onset_array = onset_SOP(audiofile)*fs

#Plot Onsets
plt.rcParams['figure.figsize'] = (12, 2) # set plot sizes to something larger than default
plt.plot(x)
for onset in onset_array:
    plt.axvline(x=onset, color='red')

# %%
#Delete the files that have been stored previously
def delete_files_in_dir(dir_name):
    for root, dirs, files in os.walk(dir_name):
        for file in files:
            file_name = os.path.join(root,file)
            os.remove(file_name);print(file_name, 'removed');

# %%
#Check if thedirectory already exists, of not, create a new one. If it exists and it is full, it deletes the files
segments_dir = 'segments'
if not os.path.exists(segments_dir):#creating the directory
    os.mkdir(segments_dir)
else:
    delete_files_in_dir(segments_dir)
# Out:
# segments/9.wav removed
# segments/1.wav removed
# segments/35.wav removed
# segments/36.wav removed
# segments/22.wav removed
# segments/2.wav removed
# segments/52.wav removed
# segments/20.wav removed
# segments/55.wav removed
# segments/33.wav removed
# segments/29.wav removed
# segments/46.wav removed
# segments/53.wav removed
# segments/51.wav removed
# segments/49.wav removed
# segments/54.wav removed
# segments/28.wav removed
# segments/47.wav removed
# segments/60.wav removed
# segments/24.wav removed
# segments/44.wav removed
# segments/3.wav removed
# segments/42.wav removed
# segments/58.wav removed
# segments/26.wav removed
# segments/59.wav removed
# segments/12.wav removed
# segments/19.wav removed
# segments/8.wav removed
# segments/15.wav removed
# segments/48.wav removed
# segments/43.wav removed
# segments/23.wav removed
# segments/27.wav removed
# segments/5.wav removed
# segments/40.wav removed
# segments/10.wav removed
# segments/45.wav removed
# segments/57.wav removed
# segments/4.wav removed
# segments/32.wav removed
# segments/14.wav removed
# segments/39.wav removed
# segments/31.wav removed
# segments/61.wav removed
# segments/21.wav removed
# segments/37.wav removed
# segments/30.wav removed
# segments/11.wav removed
# segments/56.wav removed
# segments/50.wav removed
# segments/18.wav removed
# segments/41.wav removed
# segments/6.wav removed
# segments/17.wav removed
# segments/0.wav removed
# segments/13.wav removed
# segments/38.wav removed
# segments/25.wav removed
# segments/7.wav removed
# segments/34.wav removed
# segments/16.wav removed

# %%
#Separate each note to a different file
file_count = 0
onset_shift = 2700
segment_files = []
x_seg=0
for i in range(len(onset_array)-1):
    start = int(onset_array[i])-onset_shift
    stop = int(onset_array[i+1])-onset_shift
    if stop - start > fs/3:#let's only keep segments larger than 1/3 second
        x_seg = x[start:stop]
        #Final check for amplitude (to avoid silent segments selection due to noise in split function)
        if(np.max(np.abs(x_seg)) > 0.05):
            #Amplitude normalisation
            x_seg = x_seg / np.max(np.abs(x_seg))
            filename = os.path.join(segments_dir, str(file_count) + '.wav')
            es.MonoWriter(filename = filename, format = 'wav', sampleRate = fs)(x_seg)
            file_count +=1
            segment_files.append(filename)
            
print(len(segment_files),'segment files created')
# Out:
# 62 segment files created

# %%
#Check the results
j = 0
for i in range(len(segment_files)):
    x = es.MonoLoader(filename=segment_files[i])()
    plt.plot(x)
    if j==4:
        plt.show()
        j=0
    j=j+1

# %%
#Create a full directory path for each file of the input data
def get_file_paths(path):
    sound_files = os.listdir(path)
    segments_dir = []
    for i in range(len(sound_files)):
        filepath = os.path.join(path, sound_files[i])
        segments_dir.append(filepath)
    return segments_dir

# %%
#Create the files paths from the segment files
segments_files_path = get_file_paths(segments_dir)
segments_files_path
# Out:
# ['segments/9.wav',
#  'segments/1.wav',
#  'segments/35.wav',
#  'segments/36.wav',
#  'segments/22.wav',
#  'segments/2.wav',
#  'segments/52.wav',
#  'segments/20.wav',
#  'segments/55.wav',
#  'segments/33.wav',
#  'segments/29.wav',
#  'segments/46.wav',
#  'segments/53.wav',
#  'segments/51.wav',
#  'segments/49.wav',
#  'segments/54.wav',
#  'segments/28.wav',
#  'segments/47.wav',
#  'segments/60.wav',
#  'segments/24.wav',
#  'segments/44.wav',
#  'segments/3.wav',
#  'segments/42.wav',
#  'segments/58.wav',
#  'segments/26.wav',
#  'segments/59.wav',
#  'segments/12.wav',
#  'segments/19.wav',
#  'segments/8.wav',
#  'segments/15.wav',
#  'segments/48.wav',
#  'segments/43.wav',
#  'segments/23.wav',
#  'segments/27.wav',
#  'segments/5.wav',
#  'segments/40.wav',
#  'segments/10.wav',
#  'segments/45.wav',
#  'segments/57.wav',
#  'segments/4.wav',
#  'segments/32.wav',
#  'segments/14.wav',
#  'segments/39.wav',
#  'segments/31.wav',
#  'segments/61.wav',
#  'segments/21.wav',
#  'segments/37.wav',
#  'segments/30.wav',
#  'segments/11.wav',
#  'segments/56.wav',
#  'segments/50.wav',
#  'segments/18.wav',
#  'segments/41.wav',
#  'segments/6.wav',
#  'segments/17.wav',
#  'segments/0.wav',
#  'segments/13.wav',
#  'segments/38.wav',
#  'segments/25.wav',
#  'segments/7.wav',
#  'segments/34.wav',
#  'segments/16.wav']
